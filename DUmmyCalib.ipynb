# %%
import uproot
import matplotlib.pyplot as plt 
import numpy as np
from scipy.signal import find_peaks


file=uproot.open("C:\\Users\\lemas\\OneDrive\\Desktop\\DUmmyCalib.root")
file["Energy/_R_EnergyCH1@VX2740B_15238;1"]

hist=file["Energy/_R_EnergyCH1@VX2740B_15238;1"]
hy=hist.values()
hx=hist.axis().edges()[0:len(hy)]



fig,ax=plt.subplots()
plt.plot(hx,hy)
plt.axvline(1280, color = 'green', linestyle = 'dotted', label = 'Fe-55 line')
plt.axvline(1410, color = 'green', linestyle = 'dotted', label = 'Fe-55 line')
plt.axvline(905, color = 'lightgreen', linestyle = 'dotted', label = 'Silicon Escape Peak')
plt.legend()
plt.yscale('log')
plt.xlim(0,3000)
# Out:
# (0.0, 3000.0)
